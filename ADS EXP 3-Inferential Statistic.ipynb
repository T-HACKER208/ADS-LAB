# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
bata_RelianceDataMart=pd.read_excel('/content/RelianceDataMart.xlsx')
bata_RelianceDataMart
# Out:
#     Rice_Bag_Weight
# 0             24.50
# 1             24.70
# 2             25.60
# 3             25.00
# 4             24.70
# 5             23.30
# 6             23.30
# 7             24.00
# 8             25.10
# 9             24.30
# 10            23.30
# 11            24.10
# 12            24.10
# 13            24.20
# 14            25.20
# 15            24.90
# 16            24.70
# 17            24.10
# 18            25.00
# 19            24.70
# 20            24.90
# 21            25.00
# 22            24.00
# 23            23.98
# 24            24.30
# 25            24.20
# 26            24.56
# 27            24.50
# 28            24.70

# %%
print(bata_RelianceDataMart.mean())
# Out:
# Rice_Bag_Weight    24.446207
# dtype: float64

# %%
bata_RelianceDataMart.describe()
# Out:
#        Rice_Bag_Weight
# count        29.000000
# mean         24.446207
# std           0.569463
# min          23.300000
# 25%          24.100000
# 50%          24.500000
# 75%          24.900000
# max          25.600000

# %%
one_sample_result=stats.ttest_1samp(bata_RelianceDataMart,24.446)
print(one_sample_result)
# Out:
# TtestResult(statistic=array([0.00195653]), pvalue=array([0.99845279]), df=array([28]))

# %%
bata_Pre_Post_Score=pd.read_excel('/content/Pre_Post_Score.xlsx')
bata_Pre_Post_Score
# Out:
#     Pre_Score  Post_Score  Diff
# 0          18          22    -4
# 1          21          25    -4
# 2          16          17    -1
# 3          22          24    -2
# 4          19          16     3
# 5          24          29    -5
# 6          17          20    -3
# 7          21          23    -2
# 8          23          19     4
# 9          18          20    -2
# 10         14          15    -1
# 11         16          15     1
# 12         16          18    -2
# 13         19          26    -7
# 14         18          18     0
# 15         20          24    -4
# 16         12          18    -6
# 17         22          25    -3
# 18         15          19    -4
# 19         17          16     1

# %%
two_sample_result=stats.ttest_rel (bata_Pre_Post_Score ["Pre_Score"], bata_Pre_Post_Score ["Post_Score"])

two_sample_result
# Out:
# TtestResult(statistic=-3.231252665580312, pvalue=0.004394965993185664, df=19)

# %%
bata_Crocin_Data_ST=pd.read_excel('/content/Crocin_Data_ST.xlsx')
bata_Crocin_Data_ST
# Out:
#     Before_Crocin  After_Crocin  diff
# 0           101.0            99   2.0
# 1            99.0            98   1.0
# 2           101.0            97   4.0
# 3            99.9            99   0.9
# 4            99.8            98   1.8
# 5            98.0            97   1.0
# 6            97.0            99  -2.0
# 7           101.0            98   3.0
# 8           102.0            96   6.0
# 9           103.0            98   5.0
# 10           99.0            94   5.0
# 11           99.9            96   3.9
# 12           99.8            97   2.8
# 13           99.7            99   0.7
# 14          101.1            98   3.1
# 15          102.3            97   5.3
# 16          101.0            99   2.0
# 17           99.0            98   1.0
# 18          101.0            97   4.0
# 19           99.9            99   0.9
# 20           99.8            98   1.8
# 21           98.0            96   2.0
# 22           97.0            97   0.0
# 23          101.0            99   2.0
# 24          102.0            97   5.0
# 25          103.0            99   4.0
# 26           99.0            98   1.0
# 27           99.9            97   2.9
# 28           99.8            99   0.8

# %%
two_sample_result1=stats.ttest_rel (bata_Crocin_Data_ST ["Before_Crocin"], bata_Crocin_Data_ST ["After_Crocin"])

two_sample_result1
# Out:
# TtestResult(statistic=7.071712959273876, pvalue=1.0800112658101922e-07, df=28)
