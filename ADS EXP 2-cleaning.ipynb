# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("/content/CountryAgeSalary.xlsx")

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
x = df.iloc[: , 0:3].values
y= df.iloc[: , -1].values

# %%
x
# Out:
# array([['France', 44.0, 72000.0],
#        ['Spain', 27.0, 48000.0],
#        ['Germany', 30.0, 54000.0],
#        ['Spain', 38.0, 61000.0],
#        ['Germany', 40.0, nan],
#        ['France', 35.0, 58000.0],
#        ['Spain', nan, 52000.0],
#        ['France', 48.0, 79000.0],
#        ['Germany', 50.0, 83000.0],
#        ['France', 37.0, 67000.0]], dtype=object)

# %%
y
# Out:
# array(['No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes'],
#       dtype=object)

# %%
from sklearn.impute import SimpleImputer

# %% [markdown]
# # Strategy Mean

# %%
imputer = SimpleImputer(missing_values=np.NaN , strategy = 'mean')
x[: , 1:] = imputer.fit_transform(x[: , 1:])
print(x)
# Out:
# [['France' 44.0 72000.0]
#  ['Spain' 27.0 48000.0]
#  ['Germany' 30.0 54000.0]
#  ['Spain' 38.0 61000.0]
#  ['Germany' 40.0 63777.77777777778]
#  ['France' 35.0 58000.0]
#  ['Spain' 38.77777777777778 52000.0]
#  ['France' 48.0 79000.0]
#  ['Germany' 50.0 83000.0]
#  ['France' 37.0 67000.0]]

# %%
df.Age = imputer.fit_transform(df['Age'].values.reshape(-1 , 1))[: , 0]
df
# Out:
#    Country        Age   Salary Purchased
# 0   France  44.000000  72000.0        No
# 1    Spain  27.000000  48000.0       Yes
# 2  Germany  30.000000  54000.0        No
# 3    Spain  38.000000  61000.0        No
# 4  Germany  40.000000      NaN       Yes
# 5   France  35.000000  58000.0       Yes
# 6    Spain  38.777778  52000.0        No
# 7   France  48.000000  79000.0       Yes
# 8  Germany  50.000000  83000.0        No
# 9   France  37.000000  67000.0       Yes

# %%
df.Salary = imputer.fit_transform(df['Salary'].values.reshape(-1 , 1))[: , 0]
df
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  63777.777778       Yes
# 5   France  35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes

# %% [markdown]
# # Strategy Median

# %%
df=pd.read_excel("/content/CountryAgeSalary.xlsx")

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
imputer_median = SimpleImputer(missing_values=np.NaN , strategy = 'median')

# %%
df.Age = imputer_median.fit_transform(df['Age'].values.reshape(-1 , 1))[: , 0]
df.Salary = imputer_median.fit_transform(df['Salary'].values.reshape(-1 , 1))[: , 0]
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  61000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  38.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# #Strategy Mode

# %%
df=pd.read_excel("/content/CountryAgeSalary.xlsx")

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
imputer_mode = SimpleImputer(missing_values=np.NaN , strategy = 'mode')

# %%
df.Age = imputer_median.fit_transform(df['Age'].values.reshape(-1 , 1))[: , 0]
df.Salary = imputer_median.fit_transform(df['Salary'].values.reshape(-1 , 1))[: , 0]
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  61000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  38.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# #Strategy most frequent

# %%
df=pd.read_excel("/content/CountryAgeSalary.xlsx")

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
imputer_freq = SimpleImputer(missing_values=np.NaN , strategy = 'most_frequent')

# %%
df.Age = imputer_freq.fit_transform(df['Age'].values.reshape(-1 , 1))[: , 0]
df.Salary = imputer_freq.fit_transform(df['Salary'].values.reshape(-1 , 1))[: , 0]
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  48000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  27.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# #Const

# %%
df=pd.read_excel("/content/CountryAgeSalary.xlsx")

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
imputer_const = SimpleImputer(missing_values=np.NaN , strategy = 'constant'  , fill_value=99 )

# %%
df.Age = imputer_const.fit_transform(df['Age'].values.reshape(-1 , 1))[: , 0]
df.Salary = imputer_const.fit_transform(df['Salary'].values.reshape(-1 , 1))[: , 0]
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0     99.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  99.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# #One hot Encoding

# %%
one_hot_encoded = pd.get_dummies(df['Purchased'])

# %%
df_encoded = pd.concat([df, one_hot_encoded], axis=1)

# %%
df_encoded.drop('Purchased', axis=1, inplace=True)

# %%
print(df_encoded)
# Out:
#    Country   Age   Salary     No    Yes
# 0   France  44.0  72000.0   True  False
# 1    Spain  27.0  48000.0  False   True
# 2  Germany  30.0  54000.0   True  False
# 3    Spain  38.0  61000.0   True  False
# 4  Germany  40.0     99.0  False   True
# 5   France  35.0  58000.0  False   True
# 6    Spain  99.0  52000.0   True  False
# 7   France  48.0  79000.0  False   True
# 8  Germany  50.0  83000.0   True  False
# 9   France  37.0  67000.0  False   True

# %% [markdown]
# #Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
df_encoded['Country_encoded'] = label_encoder.fit_transform(df_encoded['Country'])

# %%
df_encoded
# Out:
#    Country   Age   Salary     No    Yes  Country_encoded
# 0   France  44.0  72000.0   True  False                0
# 1    Spain  27.0  48000.0  False   True                2
# 2  Germany  30.0  54000.0   True  False                1
# 3    Spain  38.0  61000.0   True  False                2
# 4  Germany  40.0     99.0  False   True                1
# 5   France  35.0  58000.0  False   True                0
# 6    Spain  99.0  52000.0   True  False                2
# 7   France  48.0  79000.0  False   True                0
# 8  Germany  50.0  83000.0   True  False                1
# 9   France  37.0  67000.0  False   True                0
